# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from sqlalchemy) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sqlalchemy) (3.0.3)

# %%
# !pip install pyodbc
# Out:
# Collecting pyodbc
#   Downloading pyodbc-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading pyodbc-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (334 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.7/334.7 kB 7.4 MB/s eta 0:00:00:00:01
# Installing collected packages: pyodbc
# Successfully installed pyodbc-5.1.0

# %%
pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 6.9 MB/s eta 0:00:00:00:01
# Downloading pymongo-4.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (669 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.1/669.1 kB 16.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install mysqlclient
# Out:
# Collecting mysqlclient
#   Downloading mysqlclient-2.2.4.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: mysqlclient
#   Building wheel for mysqlclient (pyproject.toml) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.4-cp310-cp310-linux_x86_64.whl size=132266 sha256=7cc064c72c577a7a8864141bcac2af1ac3cf4d7ab69d5aca834bd15304e1ce15
#   Stored in directory: /home/codespace/.cache/pip/wheels/ac/96/ac/2a4d8cb58a4d95de1dffc3f8b0ea42e0e5b63ab97640edbda3
# Successfully built mysqlclient
# Installing collected packages: mysqlclient
# Successfully installed mysqlclient-2.2.4

# %%
# !pip install certifi
# Out:
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (2024.2.2)

# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd
from pymongo import MongoClient
# import pymongo
# import ssl

# %%
# Conexion a MySQL (una base de datos)
# engine = motor de MySQL
# conn = conexión

'''
Usar sqlalchemy para crear motor BD

db.create_engine("mota_bd_a_usar://user:password@IP:puerto/BD")
'''


engine = db.create_engine("mysql://root:root@172.16.5.4:3310/retail_db")
conn = engine.connect()

# %%
df_customers = pd.read_sql_query('SELECT * FROM customers',con = conn)
df_customers.tail()
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 12430         XXXXXXXXX           1221 Cinder Pines       Kaneohe
# 12431         XXXXXXXXX  1525 Jagged Barn Highlands        Caguas
# 12432         XXXXXXXXX    5459 Noble Brook Landing     Levittown
# 12433         XXXXXXXXX        9720 Colonial Parade        Caguas
# 12434         XXXXXXXXX            5736 Honey Downs   Summerville
#
#       customer_state customer_zipcode
# 12430             HI            96744
# 12431             PR            00725
# 12432             NY            11756
# 12433             PR            00725
# 12434             SC            29483

# %%
# Indicarle a Mongo que vamos a trabajar sobre esta database
dbname = client['retail_db']

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Conectar con MongoDB y mandar los datos del database de MySQL

uri = "mongodb+srv://paulinamarin3105:RrVmNa16bx6hb6Qu@cluster0.clf2lmd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# En Mongo se puede crear un database pero no se va a ver reflejado aún en cloud (atlas) cuando le insertemos datos
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# !pip install --upgrade pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/python/3.10.13/lib/python3.10/site-packages (4.7.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pymongo) (2.6.1)

# %%
# Llevar datos al database. Mongo trabaja con colecciones, que son como las tablas en MySQL. Si tengo un dabase tambien debo tener mis colecciones

# No es necesario, pero es recomendado tener una copia del df original
df = df_customers.copy()

# Mongo almacena documetos por ello hay que almacenar el df como un diccionario para almacenarlo en un JSON que es compatible con Mongo
df_to_dict = df.to_dict("records") # records = parametros para indica registros o filas sea los elementos del diccionario

# Mandar datos a Mongo
'''
insert_many = Para insertar un dataframe completo
insert_one = Para insertar un registro del dataframe

dbname["collection_name"].insert_many(records_dict)
'''

dbname["customers"].insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('666dd15c506731dd3fab7a78'), ObjectId('666dd15c506731dd3fab7a79'), ObjectId('666dd15c506731dd3fab7a7a'), ObjectId('666dd15c506731dd3fab7a7b'), ObjectId('666dd15c506731dd3fab7a7c'), ObjectId('666dd15c506731dd3fab7a7d'), ObjectId('666dd15c506731dd3fab7a7e'), ObjectId('666dd15c506731dd3fab7a7f'), ObjectId('666dd15c506731dd3fab7a80'), ObjectId('666dd15c506731dd3fab7a81'), ObjectId('666dd15c506731dd3fab7a82'), ObjectId('666dd15c506731dd3fab7a83'), ObjectId('666dd15c506731dd3fab7a84'), ObjectId('666dd15c506731dd3fab7a85'), ObjectId('666dd15c506731dd3fab7a86'), ObjectId('666dd15c506731dd3fab7a87'), ObjectId('666dd15c506731dd3fab7a88'), ObjectId('666dd15c506731dd3fab7a89'), ObjectId('666dd15c506731dd3fab7a8a'), ObjectId('666dd15c506731dd3fab7a8b'), ObjectId('666dd15c506731dd3fab7a8c'), ObjectId('666dd15c506731dd3fab7a8d'), ObjectId('666dd15c506731dd3fab7a8e'), ObjectId('666dd15c506731dd3fab7a8f'), ObjectId('666dd15c506731dd3fab7a90'), ObjectId('666dd15c506731dd3fab7a91'), ObjectId('666dd15c506731dd3fab7a92'), ObjectId('666dd15c506731dd3fab7a93'), ObjectId('666dd15c506731dd3fab7a94'), ObjectId('666dd15c506731dd3fab7a95'), ObjectId('666dd15c506731dd3fab7a96'), ObjectId('666dd15c506731dd3fab7a97'), ObjectId('666dd15c506731dd3fab7a98'), ObjectId('666dd15c506731dd3fab7a99'), ObjectId('666dd15c506731dd3fab7a9a'), ObjectId('666dd15c506731dd3fab7a9b'), ObjectId('666dd15c506731dd3fab7a9c'), ObjectId('666dd15c506731dd3fab7a9d'), ObjectId('666dd15c506731dd3fab7a9e'), ObjectId('666dd15c506731dd3fab7a9f'), ObjectId('666dd15c506731dd3fab7aa0'), ObjectId('666dd15c506731dd3fab7aa1'), ObjectId('666dd15c506731dd3fab7aa2'), ObjectId('666dd15c506731dd3fab7aa3'), ObjectId('666dd15c506731dd3fab7aa4'), ObjectId('666dd15c506731dd3fab7aa5'), ObjectId('666dd15c506731dd3fab7aa6'), ObjectId('666dd15c506731dd3fab7aa7'), ObjectId('666dd15